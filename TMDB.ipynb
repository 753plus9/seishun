jets over the Atlantic, forcing the U.S. to fill the sky with its own fighters trying to stop the high-tech SU-57 squadrons before they ravage Washington, D.C.","popularity":3.877,"poster_path":"/v1jtS5Im8RCJJt4WXSZBBnMXgEe.jpg","release_date":"2023-09-01","title":"Top Gunner: America vs. Russia","video":false,"vote_average":4.5,"vote_count":4},{"adult":false,"backdrop_path":"/kjRFf4mbBQZ3NDwF3MM1eRKqZfB.jpg","genre_ids":[28],"id":714351,"original_language":"en","original_title":"Top Gunner","overview":"Recent graduates of a secluded U.S. Air Force base must protect a gene-editing bioweapon from the Russian military—who are desperate to seize the deadly viral agent at any cost.","popularity":7.174,"poster_path":"/w3pYxiYHcPlEIW44RYdQgNQESvE.jpg","release_date":"2020-06-23","title":"Top Gunner","video":false,"vote_average":5.5,"vote_count":111},{"adult":false,"backdrop_path":null,"genre_ids":[28,18],"id":1229934,"original_language":"en","original_title":"Top Gun 3","overview":"Sequel to Top Gun: Maverick (2022) and third entry in the “Top Gun” franchise. Plot TBA.","popularity":4.981,"poster_path":"/ypuc9E4JnkvHmwo3qNNFOnJREsN.jpg","release_date":"","title":"Top Gun 3","video":false,"vote_average":0.0,"vote_count":0},{"adult":false,"backdrop_path":"/l1GmkC9EJLDVRt8RxT64cet6QUQ.jpg","genre_i ...

# %% [markdown]
# pythonコード百科事典（https://python-codes.net/entry/python-tmdb-api）の人気映画情報取得のコードを参照（というかコピペ）

# %%
import requests
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
# APIのURLを生成
url = "https://api.themoviedb.org/3/movie/now_playing"
# APIを呼び出す
response = requests.get(url, params={"api_key": api_key})
# 結果を表示
if response.status_code == 200:
# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    data = response.json()
# 映画の一覧を表示
    for movie in data["results"]:
        print(movie["title"])
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# Venom: The Last Dance
# Moana 2
# Elevation
# Absolution
# Watchmen: Chapter II
# Miraculous World, London: At the Edge of Time
# Armor
# Sidelined: The QB and Me
# Gladiator II
# Sikandar Ka Muqaddar
# The Wild Robot
# That Christmas
# Red One
# GTMAX
# Wicked
# Kraven the Hunter
# The Substance
# Terrifier 3
# Hunting With Tigers
# Solo Leveling -ReAwakening-

# %% [markdown]
# 上記のコードを参考にしてアレンジ、
# TMDB API Referenceの　SEARCH＞Movieに記載されている内容を読み、paramsを設定して、映画タイトルから映画IDを取得
# (確認のため、映画タイトルとオリジナルタイトルも表示）)
# 「トップ・ガン」だと２種類検出された。

# %%
import requests
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
url = "https://api.themoviedb.org/3/search/movie"

# APIリクエストパラメータ
params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
response = requests.get(url, params=params)
# 結果を表示
if response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    data = response.json()
    for movie in data["results"]:
        print(movie["id"], movie["title"],movie["original_title"])
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# 361743 トップガン マーヴェリック Top Gun: Maverick
# 744 トップガン Top Gun

# %% [markdown]
# 試しに、一つ目に絞ると、トップガンマーヴェリックのほうが抽出されるので、NG

# %%
import requests
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
url = "https://api.themoviedb.org/3/search/movie"

    # APIリクエストパラメータ
params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
response = requests.get(url, params=params)
# 結果を表示
if response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    data = response.json()
    first_movie = data["results"][0]
    print(
        first_movie.get("id"), 
        first_movie.get("title"), 
        first_movie.get("original_title")
    )
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# 361743 トップガン マーヴェリック Top Gun: Maverick

# %% [markdown]
# タイトル名が最も近いものを一つだけ選択するコードに変更

# %%
import requests
import difflib

# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
url = "https://api.themoviedb.org/3/search/movie"

# APIリクエストパラメータ
params = {
    "api_key": api_key,
    "query": title,
    "include_adult": "false",
    "language": "ja",  
}
    
# APIを呼び出す
response = requests.get(url, params=params)

# 結果を表示
if response.status_code == 200:
    # レスポンスのJSONを取得
    data = response.json()
    
    # タイトルの類似度を評価して最も近い映画を選択
    def get_title_similarity(s1, s2):
        return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()
    
    # 入力したtitleとの類似度が最も高い映画を選択
    most_similar_movie = max(
        data["results"], 
        key=lambda movie: get_title_similarity(movie["title"], title)
    )
    
    print(most_similar_movie["id"], most_similar_movie["title"])
else:
    print("API Error")
# Out:
# 744 トップガン

# %% [markdown]
# 取得した映画ＩＤを使って、Detailsにある映画情報データを取得する。エンドポイントのurlを区別するため、
# 映画ＩＤ取得用ＵＲＬ:search_url 　　映画情報取得用ＵＲＬ：detail_url　とネーミング
# 試しに、映画情報取得用ＵＲＬから取得した「タイトル」「オリジナルタイトル」と「映画概要（overview）」を表示

# %%
import requests
import difflib
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
search_url = "https://api.themoviedb.org/3/search/movie"

# APIリクエストパラメータ
search_params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
search_response = requests.get(search_url, params=search_params)
# 結果を表示
if search_response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    search_data = search_response.json()
    # タイトルの類似度を評価して最も近い映画を選択
    def get_title_similarity(s1, s2):
        return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()
    
    # 入力したtitleとの類似度が最も高い映画を選択
    most_similar_movie = max(
        data["results"], 
        key=lambda movie: get_title_similarity(movie["title"], title)
    )
else:
# ステータスコードが200以外の場合
    print("API Error")

movie_id = most_similar_movie["id"]

# 映画詳細情報の取得   
detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"


detail_params = {
    "api_key": api_key, 
    "language": "ja",
}    
    
detail_response = requests.get(detail_url, params= detail_params)

if detail_response.status_code == 200:
    detail_data = detail_response.json()
    detail_title = detail_data.get("title")
    original_title = detail_data.get("original_title")
    overview = detail_data.get("overview")
    print("title : ", detail_title)
    print("original title :", original_title)
    print("overview :", overview)
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# title :  トップガン
# original title : Top Gun
# overview : カリフォルニア州ミラマー海軍航空基地。そこにF－14トムキャットを操る世界最高のパイロットたちを養成する訓練学校、通称“トップガン”がある。若きパイロットのマーヴェリックもパートナーのグースとともにこのトップガン入りを果たし、自信と野望を膨らませる。日々繰り返される厳しい訓練も、マーヴェリックはグースとの絶妙なコンビネーションで次々と課題をクリアしていく。しかしライバルのアイスマンは、彼の型破りな操縦を無謀と指摘する。その一方で、マーヴェリックは新任の女性教官チャーリーに心奪われていく。

# %% [markdown]
# 映画情報取得用ＵＲＬから、「リリース日」「映画の長さ」「評価スコア」「評価数」「レコメンデーション」を取得
# また、ポスター画像取得用ＵＲＬから「ポスター画像」を取得

# %%
import requests
import difflib
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
search_url = "https://api.themoviedb.org/3/search/movie"

    # APIリクエストパラメータ
search_params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
search_response = requests.get(search_url, params=search_params)
# 結果を表示
if search_response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    search_data = search_response.json()
    # タイトルの類似度を評価して最も近い映画を選択
    def get_title_similarity(s1, s2):
        return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()
    
    # 入力したtitleとの類似度が最も高い映画を選択
    most_similar_movie = max(
        search_data["results"], 
        key=lambda movie: get_title_similarity(movie["title"], title)
    )
else:
# ステータスコードが200以外の場合
    print("API Error")

movie_id = most_similar_movie["id"]

# 映画詳細情報の取得     
detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"

detail_params = {
    "api_key": api_key, 
    "language": "ja",
}    
    
detail_response = requests.get(detail_url, params= detail_params)

if detail_response.status_code == 200:
    detail_data = detail_response.json()
    detail_title = detail_data.get("title")
    original_title = detail_data.get("original_title")
    overview = detail_data.get("overview")
    release_date = detail_data.get("release_date")
    runtime = detail_data.get("runtime")
    vote_average = detail_data.get("vote_average")
    vote_count = detail_data.get("vote_count")
    
    print("title : ", detail_title)
    print("original title :", original_title)
    print("overview :", overview)
    print("release_date : ", release_date)
    print("runtime:", runtime)
    print("vote_average :", vote_average)
    print("vote_count :", vote_count)
else:
# ステータスコードが200以外の場合
    print("API Error")
    
# ポスター画像の取得
images_url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
poster_size = "w500" 

images_params = {
    "api_key": api_key, 
    "include_image_language": "ja",
}   

images_response = requests.get(images_url, images_params)
if images_response.status_code == 200:
    images_data = images_response.json()
    posters = images_data.get("posters")
    file_path = posters[0].get("file_path")
    rile_path_url = f"{images_url}{poster_size}{file_path}"
    
    print("file_path : ", file_path)
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# title :  トップガン
# original title : Top Gun
# overview : カリフォルニア州ミラマー海軍航空基地。そこにF－14トムキャットを操る世界最高のパイロットたちを養成する訓練学校、通称“トップガン”がある。若きパイロットのマーヴェリックもパートナーのグースとともにこのトップガン入りを果たし、自信と野望を膨らませる。日々繰り返される厳しい訓練も、マーヴェリックはグースとの絶妙なコンビネーションで次々と課題をクリアしていく。しかしライバルのアイスマンは、彼の型破りな操縦を無謀と指摘する。その一方で、マーヴェリックは新任の女性教官チャーリーに心奪われていく。
# release_date :  1986-05-16
# runtime: 110
# vote_average : 7.055
# vote_count : 8574
# file_path :  /pr0985VzJxMiQqXabYHTlSgVWRy.jpg

# %% [markdown]
# 試しにレコメンド情報を「recommendations」から取得したが、今回は不要。

# %%
import requests
import difflib
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
search_url = "https://api.themoviedb.org/3/search/movie"

    # APIリクエストパラメータ
search_params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
search_response = requests.get(search_url, params=search_params)
# 結果を表示
if search_response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    search_data = search_response.json()
    # タイトルの類似度を評価して最も近い映画を選択
    def get_title_similarity(s1, s2):
        return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()
    
    # 入力したtitleとの類似度が最も高い映画を選択
    most_similar_movie = max(
        search_data["results"], 
        key=lambda movie: get_title_similarity(movie["title"], title)
    )
else:
# ステータスコードが200以外の場合
    print("API Error")

movie_id = most_similar_movie["id"]

# 映画詳細情報の取得     
detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"

detail_params = {
    "api_key": api_key, 
    "language": "ja",
}    
    
detail_response = requests.get(detail_url, params= detail_params)

if detail_response.status_code == 200:
    detail_data = detail_response.json()
    detail_title = detail_data.get("title")
    original_title = detail_data.get("original_title")
    overview = detail_data.get("overview")
    release_date = detail_data.get("release_date")
    runtime = detail_data.get("runtime")
    vote_average = detail_data.get("vote_average")
    vote_count = detail_data.get("vote_count")
    
    print("title : ", detail_title)
    print("original title :", original_title)
    print("overview :", overview)
    print("release_date : ", release_date)
    print("runtime:", runtime)
    print("vote_average :", vote_average)
    print("vote_count :", vote_count)
else:
# ステータスコードが200以外の場合
    print("API Error")
    
# ポスター画像の取得
images_url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
poster_size = "w500" 

images_params = {
    "api_key": api_key, 
    "include_image_language": "ja",
}   

images_response = requests.get(images_url, images_params)
if images_response.status_code == 200:
    images_data = images_response.json()
    posters = images_data.get("posters")
    file_path = posters[0].get("file_path")
    rile_path_url = f"{images_url}{poster_size}{file_path}"
    
    print("file_path : ", file_path)
else:
# ステータスコードが200以外の場合
    print("API Error")
    
recommend_url = f"https://api.themoviedb.org/3/movie/{movie_id}/recommendations"

recommend_params = {
    "api_key": api_key, 
    "language": "ja",
}    
    
recommend_response = requests.get(recommend_url, params= recommend_params)

if recommend_response.status_code == 200:
    recommend_data = recommend_response.json()
    recommendations = recommend_data.get("results", [])
    if recommendations:
        print("Recommendations:")
        for movie in recommendations:
            print(f"- {movie.get('title')} ({movie.get('release_date')})")
    else:
        print("No recommendations found.")

else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# title :  トップガン
# original title : Top Gun
# overview : カリフォルニア州ミラマー海軍航空基地。そこにF－14トムキャットを操る世界最高のパイロットたちを養成する訓練学校、通称“トップガン”がある。若きパイロットのマーヴェリックもパートナーのグースとともにこのトップガン入りを果たし、自信と野望を膨らませる。日々繰り返される厳しい訓練も、マーヴェリックはグースとの絶妙なコンビネーションで次々と課題をクリアしていく。しかしライバルのアイスマンは、彼の型破りな操縦を無謀と指摘する。その一方で、マーヴェリックは新任の女性教官チャーリーに心奪われていく。
# release_date :  1986-05-16
# runtime: 110
# vote_average : 7.055
# vote_count : 8574
# file_path :  /pr0985VzJxMiQqXabYHTlSgVWRy.jpg
# Recommendations:
# - トップガン マーヴェリック (2022-05-21)
# - ランボー3／怒りのアフガン (1988-05-24)
# - 4デイズ (2010-06-14)
# - カクテル (1988-07-29)
# - The Vanishing (1988-10-27)
# - ダウト〜あるカトリック学校で〜 (2008-12-12)
# - レインマン (1988-12-12)
# - ア・フュー・グッドメン (1992-12-11)
# - 卒業白書 (1983-08-05)
# - デイズ・オブ・サンダー (1990-06-27)
# - アメリカ物語 (1986-11-21)
# - ジェントルメン (2020-01-01)
# - ホーム・アローン (1990-11-16)
# - ザ・エージェント (1996-12-13)
# - ラスト・サムライ (2003-12-05)
# - ハスラー2 (1986-10-17)
# - ベスト・キッド (2010-06-10)
# - ホット・ショット (1991-07-31)
# - フレンチ・ディスパッチ ザ・リバティ、カンザス・イヴニング・サン別冊 (2021-10-21)
# - コラテラル (2004-08-04)

# %% [markdown]
# 製作者(crew)、俳優（cast）の情報を「Credits」から取得する。

# %%
import requests
import difflib
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
search_url = "https://api.themoviedb.org/3/search/movie"

    # APIリクエストパラメータ
search_params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
search_response = requests.get(search_url, params=search_params)
# 結果を表示
if search_response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    search_data = search_response.json()
    # タイトルの類似度を評価して最も近い映画を選択
    def get_title_similarity(s1, s2):
        return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()
    
    # 入力したtitleとの類似度が最も高い映画を選択
    most_similar_movie = max(
        search_data["results"], 
        key=lambda movie: get_title_similarity(movie["title"], title)
    )
else:
# ステータスコードが200以外の場合
    print("API Error")

movie_id = most_similar_movie["id"]

# 映画詳細情報の取得    
detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"

detail_params = {
    "api_key": api_key, 
    "language": "ja",
}    
    
detail_response = requests.get(detail_url, params= detail_params)

if detail_response.status_code == 200:
    detail_data = detail_response.json()
    detail_title = detail_data.get("title")
    original_title = detail_data.get("original_title")
    overview = detail_data.get("overview")
    release_date = detail_data.get("release_date")
    runtime = detail_data.get("runtime")
    vote_average = detail_data.get("vote_average")
    vote_count = detail_data.get("vote_count")
    
    print("title : ", detail_title)
    print("original title :", original_title)
    print("overview :", overview)
    print("release_date : ", release_date)
    print("runtime:", runtime)
    print("vote_average :", vote_average)
    print("vote_count :", vote_count)
else:
# ステータスコードが200以外の場合
    print("API Error")
    
# ポスター画像の取得
images_url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
poster_size = "w500" 

images_params = {
    "api_key": api_key, 
    "include_image_language": "ja",
}   

images_response = requests.get(images_url, images_params)
if images_response.status_code == 200:
    images_data = images_response.json()
    posters = images_data.get("posters")
    file_path = posters[0].get("file_path")
    rile_path_url = f"{images_url}{poster_size}{file_path}"
    
    print("file_path : ", file_path)
else:
# ステータスコードが200以外の場合
    print("API Error")

# 製作者、キャスト情報の取得
credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"

credits_params = {
    "api_key": api_key, 
    "language": "ja",
}
credits_response = requests.get(credits_url, images_params)
if credits_response.status_code == 200:
    credits_data = credits_response.json()
    crew = credits_data.get("crew")
    cast = credits_data.get("cast")

    print("crew :",crew)
    print("cast :",cast)
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# title :  トップガン
# original title : Top Gun
# overview : カリフォルニア州ミラマー海軍航空基地。そこにF－14トムキャットを操る世界最高のパイロットたちを養成する訓練学校、通称“トップガン”がある。若きパイロットのマーヴェリックもパートナーのグースとともにこのトップガン入りを果たし、自信と野望を膨らませる。日々繰り返される厳しい訓練も、マーヴェリックはグースとの絶妙なコンビネーションで次々と課題をクリアしていく。しかしライバルのアイスマンは、彼の型破りな操縦を無謀と指摘する。その一方で、マーヴェリックは新任の女性教官チャーリーに心奪われていく。
# release_date :  1986-05-16
# runtime: 110
# vote_average : 7.055
# vote_count : 8574
# file_path :  /pr0985VzJxMiQqXabYHTlSgVWRy.jpg
# crew : [{'adult': False, 'gender': 2, 'id': 771, 'known_for_department': 'Production', 'name': 'Don Simpson', 'original_name': 'Don Simpson', 'popularity': 4.071, 'profile_path': '/dSVaGMYnsRrdUj6Xn7HeOzQlMZ5.jpg', 'credit_id': '52fe426fc3a36847f801e67f', 'department': 'Production', 'job': 'Producer'}, {'adult': False, 'gender': 2, 'id': 770, 'known_for_department': 'Production', 'name': 'Jerry Bruckheimer', 'original_name': 'Jerry Bruckheimer', 'popularity': 10.333, 'profile_path': '/vTKQVRrj9vOrKLkPEsXHxmpV9c3.jpg', 'credit_id': '52fe426fc3a36847f801e685', 'department': 
department': 'Acting', 'name': 'Barry Tubb', 'original_name': 'Barry Tubb', 'popularity': 3.378, 'profile_path': '/sKzDWQWecmA5iuCxVCuMrYvn9Wf.jpg', 'cast_id': 20, 'character': 'Wolfman', 'credit_id': '52fe426fc3a36847f801e6d5', 'order': 7}, {'adult': False, 'gender': 2, 'id': 2717, 'known_for_department': 'Acting', 'name': 'Rick Rossovich', 'original_name': 'Rick Rossovich', 'popularity': 8.298, 'profile_path': '/uShNdPWbDHMejpMxuoNsqaaDbuc.jpg', 'cast_id': 21, 'character': 'Slider', 'credit_id': '52fe426fc3a36847f801e6d9', 'order': 8}, {'adult': False, 'gender': 2, 'id': 504, 'known_for_department': 'Acting', 'name': 'Tim Robbins', 'original_name': 'Tim Robbins', 'popularity': 21.871, 'profile_path': '/djLVFETFTvPyVUdrd7aLVykobof.jpg', 'cast_id': 22, 'character': 'Merlin', 'credit_id': '52fe426fc3a36847f801e6dd', 'order': 9}, {'adult': False, 'gender': 2, 'id': 51581, 'known_for_department': 'Acting', 'name': 'Clarence Gilyard Jr.', 'original_name': 'Clarence Gilyard Jr.', 'popularity': 8.121, 'profile_path': '/mTxlCE2RqtRK4NehoX70n2NKmjO.jpg', 'cast_id': 55, 'character': 'Sundown', 'credit_id': '561ddfaa92514142b800116f', 'order': 10}, {'adult': False, 'gender': 2, 'id': 11089, 'known_for_department': 'Acting', 'name': 'Whip Hubley', 'original_name': 'Whip Hubley', 'popularity': 5.672, 'profile_path': '/lqwleuUWQhLWMJ4ZvAdRGrXgvjT.jpg', 'cast_id': 24, 'character': 'Hollywood', 'credit_id': '52fe426fc3a36847f801e6e5', 'order': 11}, {'adult': False, 'gender': 2, 'id': 1072, 'known_for_department': 'Acting', 'name': 'James Tolkan', 'original_name': 'James Tolkan', 'popularity': 6.957, 'profile_path': '/euEktcyVXm1pq5UBC16v3zuBq7J.jpg', 'cast_id': 27, 'character': 'Stinger', 'credit_id': '52fe426fc3a36847f801e6ed', 'order': 12}, {'adult': False, 'gender': 1, 'id': 5344, 'known_for_department': 'Acting',  ...

# %% [markdown]
# 製作者と俳優について必要なものに絞り込みたい。
# 製作者は名前（name）と役割（job）、["Director", "Screenplay", "Producer", "Writer","composer"] の5職種にフィルタリング、俳優は名前（name）と配役（character）とする。
# いずれも上位５人分表示したい。
#
# [:5]で「５件まで」ということになる。

# %%
import requests
import difflib
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
search_url = "https://api.themoviedb.org/3/search/movie"

    # APIリクエストパラメータ
search_params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
search_response = requests.get(search_url, params=search_params)
# 結果を表示
if search_response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    search_data = search_response.json()
    # タイトルの類似度を評価して最も近い映画を選択
    def get_title_similarity(s1, s2):
        return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()
    
    # 入力したtitleとの類似度が最も高い映画を選択
    most_similar_movie = max(
        search_data["results"], 
        key=lambda movie: get_title_similarity(movie["title"], title)
    )
else:
# ステータスコードが200以外の場合
    print("API Error")

movie_id = most_similar_movie["id"]

# 映画詳細情報の取得    
detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"

detail_params = {
    "api_key": api_key, 
    "language": "ja",
}    
    
detail_response = requests.get(detail_url, params= detail_params)

if detail_response.status_code == 200:
    detail_data = detail_response.json()
    detail_title = detail_data.get("title")
    original_title = detail_data.get("original_title")
    overview = detail_data.get("overview")
    release_date = detail_data.get("release_date")
    runtime = detail_data.get("runtime")
    vote_average = detail_data.get("vote_average")
    vote_count = detail_data.get("vote_count")
    
    print("title : ", detail_title)
    print("original title :", original_title)
    print("overview :", overview)
    print("release_date : ", release_date)
    print("runtime:", runtime)
    print("vote_average :", vote_average)
    print("vote_count :", vote_count)
else:
# ステータスコードが200以外の場合
    print("API Error")
    
# ポスター画像の取得
images_url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
poster_size = "w500" 

images_params = {
    "api_key": api_key, 
    "include_image_language": "ja",
}   

images_response = requests.get(images_url, images_params)
if images_response.status_code == 200:
    images_data = images_response.json()
    posters = images_data.get("posters")
    file_path = posters[0].get("file_path")
    rile_path_url = f"{images_url}{poster_size}{file_path}"
    
    print("file_path : ", file_path)
else:
# ステータスコードが200以外の場合
    print("API Error")

# 製作者、キャストの情報取得
credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"
cast_size = "w100"
credits_params = {
    "api_key": api_key, 
    "language": "ja",
}
credits_response = requests.get(credits_url, images_params)
if credits_response.status_code == 200:
    credits_data = credits_response.json()
    print("CREW :")
    crew = credits_data.get("crew", []) 
    filtered_roles = ["Director", "Screenplay", "Producer", "Writer", "Composer"]
    filtered_crew = [
        member for member in crew if member.get("job") in filtered_roles
    ]
    for member in filtered_crew[:5]:  # 上位5人まで
        name = member.get("name", "N/A")
        job = member.get("job", "N/A")
        print(f"- {name}: {job}")
    
    print("CAST :")
    cast = credits_data.get("cast", [])
    for actor in cast[:5]:
        name = actor.get("name", "N/A")
        character = actor.get("character", "N/A")
        print(f"- {name} as {character}")
    
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# title :  トップガン
# original title : Top Gun
# overview : カリフォルニア州ミラマー海軍航空基地。そこにF－14トムキャットを操る世界最高のパイロットたちを養成する訓練学校、通称“トップガン”がある。若きパイロットのマーヴェリックもパートナーのグースとともにこのトップガン入りを果たし、自信と野望を膨らませる。日々繰り返される厳しい訓練も、マーヴェリックはグースとの絶妙なコンビネーションで次々と課題をクリアしていく。しかしライバルのアイスマンは、彼の型破りな操縦を無謀と指摘する。その一方で、マーヴェリックは新任の女性教官チャーリーに心奪われていく。
# release_date :  1986-05-16
# runtime: 110
# vote_average : 7.055
# vote_count : 8574
# file_path :  /pr0985VzJxMiQqXabYHTlSgVWRy.jpg
# CREW :
# - Don Simpson: Producer
# - Jerry Bruckheimer: Producer
# - Tony Scott: Director
# - Jim Cash: Writer
# - Jack Epps Jr.: Writer
# CAST :
# - Tom Cruise as Maverick
# - Kelly McGillis as Charlie
# - Val Kilmer as Ice
# - Anthony Edwards as Goose
# - Tom Skerritt as Viper

# %% [markdown]
# CASTには、画像を添付したい。  castの傘下にある「profile_path」というのが画像のよう。（TMDB API Reference参照）

# %%
import requests
import difflib
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン"

# APIのURLを生成
search_url = "https://api.themoviedb.org/3/search/movie"

    # APIリクエストパラメータ
search_params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
search_response = requests.get(search_url, params=search_params)
# 結果を表示
if search_response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    search_data = search_response.json()
    # タイトルの類似度を評価して最も近い映画を選択
    def get_title_similarity(s1, s2):
        return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()
    
    # 入力したtitleとの類似度が最も高い映画を選択
    most_similar_movie = max(
        search_data["results"], 
        key=lambda movie: get_title_similarity(movie["title"], title)
    )
else:
# ステータスコードが200以外の場合
    print("API Error")

movie_id = most_similar_movie["id"]

# 映画詳細情報の取得    
detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"

detail_params = {
    "api_key": api_key, 
    "language": "ja",
}    
    
detail_response = requests.get(detail_url, params= detail_params)

if detail_response.status_code == 200:
    detail_data = detail_response.json()
    detail_title = detail_data.get("title")
    original_title = detail_data.get("original_title")
    overview = detail_data.get("overview")
    release_date = detail_data.get("release_date")
    runtime = detail_data.get("runtime")
    vote_average = detail_data.get("vote_average")
    vote_count = detail_data.get("vote_count")
    
    print("title : ", detail_title)
    print("original title :", original_title)
    print("overview :", overview)
    print("release_date : ", release_date)
    print("runtime:", runtime)
    print("vote_average :", vote_average)
    print("vote_count :", vote_count)
else:
# ステータスコードが200以外の場合
    print("API Error")
    
# ポスター画像の取得
images_url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
poster_size = "w500" 

images_params = {
    "api_key": api_key, 
    "include_image_language": "ja",
}   

images_response = requests.get(images_url, images_params)
if images_response.status_code == 200:
    images_data = images_response.json()
    posters = images_data.get("posters")
    file_path = posters[0].get("file_path")
    rile_path_url = f"{images_url}{poster_size}{file_path}"
    
    print("file_path : ", file_path)
else:
# ステータスコードが200以外の場合
    print("API Error")

# 製作者、キャストの情報取得
credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"
credits_params = {
    "api_key": api_key, 
    "language": "ja",
}
credits_response = requests.get(credits_url, images_params)
if credits_response.status_code == 200:
    credits_data = credits_response.json()
    print("CREW :")
    filtered_roles = ["Director", "Screenplay", "Producer", "Writer", "Composer"]
    filtered_crew = [
        member for member in crew if member.get("job") in filtered_roles
    ]
    for member in filtered_crew[:5]:  # 上位5人まで
        name = member.get("name", "N/A")
        job = member.get("job", "N/A")
        print(f"-  {job}:{name}")
    
    print("CAST :")
    cast = credits_data.get("cast", [])
    for actor in cast[:5]:
        name = actor.get("name", "N/A")
        character = actor.get("character", "N/A")
        print(f"- {name} ({character})")
        profile_path = actor.get("profile_path", None)
        print("profile_path :", profile_path)
    
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# title :  トップガン
# original title : Top Gun
# overview : カリフォルニア州ミラマー海軍航空基地。そこにF－14トムキャットを操る世界最高のパイロットたちを養成する訓練学校、通称“トップガン”がある。若きパイロットのマーヴェリックもパートナーのグースとともにこのトップガン入りを果たし、自信と野望を膨らませる。日々繰り返される厳しい訓練も、マーヴェリックはグースとの絶妙なコンビネーションで次々と課題をクリアしていく。しかしライバルのアイスマンは、彼の型破りな操縦を無謀と指摘する。その一方で、マーヴェリックは新任の女性教官チャーリーに心奪われていく。
# release_date :  1986-05-16
# runtime: 110
# vote_average : 7.055
# vote_count : 8574
# file_path :  /pr0985VzJxMiQqXabYHTlSgVWRy.jpg
# CREW :
# -  Producer:Don Simpson
# -  Producer:Jerry Bruckheimer
# -  Director:Tony Scott
# -  Writer:Jim Cash
# -  Writer:Jack Epps Jr.
# CAST :
# - Tom Cruise (Maverick)
# profile_path : /3mShHjSQR7NXOVbdTu5rT2Qd0MN.jpg
# - Kelly McGillis (Charlie)
# profile_path : /5M1JlzKRECJCIENJrYBqSsSvUEw.jpg
# - Val Kilmer (Ice)
# profile_path : /uqX8JxI6bWs1I3BOAtzJJD0DDo6.jpg
# - Anthony Edwards (Goose)
# profile_path : /rP88gP87pa3je6Viem3081tESIV.jpg
# - Tom Skerritt (Viper)
# profile_path : /xP2BNCa5NixphQOpFCl44B0HWgW.jpg

# %% [markdown]
# レビューの追加(3人まで)

# %%
import requests
import difflib
# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"
title = "トップ・ガン・マーヴェリック"

# APIのURLを生成
search_url = "https://api.themoviedb.org/3/search/movie"

    # APIリクエストパラメータ
search_params = {
        "api_key": api_key,  # 取得したAPIキーを入力
        "query" :  title,
        "include_adult": "false",
        "language": "ja",  
    }
    
# APIを呼び出す
search_response = requests.get(search_url, params=search_params)
# 結果を表示
if search_response.status_code == 200:

# ステータスコードが200(OK)の場合
# レスポンスのJSONを取得
    search_data = search_response.json()
    # タイトルの類似度を評価して最も近い映画を選択
    def get_title_similarity(s1, s2):
        return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()
    
    # 入力したtitleとの類似度が最も高い映画を選択
    most_similar_movie = max(
        search_data["results"], 
        key=lambda movie: get_title_similarity(movie["title"], title)
    )
else:
# ステータスコードが200以外の場合
    print("API Error")

movie_id = most_similar_movie["id"]

# 映画詳細情報の取得    
detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"

detail_params = {
    "api_key": api_key, 
    "language": "ja",
}    
    
detail_response = requests.get(detail_url, params= detail_params)

if detail_response.status_code == 200:
    detail_data = detail_response.json()
    detail_title = detail_data.get("title")
    original_title = detail_data.get("original_title")
    overview = detail_data.get("overview")
    release_date = detail_data.get("release_date")
    runtime = detail_data.get("runtime")
    vote_average = detail_data.get("vote_average")
    vote_count = detail_data.get("vote_count")
    
    print("title : ", detail_title)
    print("original title :", original_title)
    print("overview :", overview)
    print("release_date : ", release_date)
    print("runtime:", runtime)
    print("vote_average :", vote_average)
    print("vote_count :", vote_count)
else:
# ステータスコードが200以外の場合
    print("API Error")
    
# ポスター画像の取得
images_url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
poster_size = "w500" 

images_params = {
    "api_key": api_key, 
    "include_image_language": "ja",
}   

images_response = requests.get(images_url, images_params)
if images_response.status_code == 200:
    images_data = images_response.json()
    posters = images_data.get("posters")
    file_path = posters[0].get("file_path")
    rile_path_url = f"{images_url}{poster_size}{file_path}"
    
    print("file_path : ", file_path)
else:
# ステータスコードが200以外の場合
    print("API Error")

# 製作者、キャストの情報取得
credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"
credits_params = {
    "api_key": api_key, 
    "language": "ja",
}
credits_response = requests.get(credits_url, images_params)
if credits_response.status_code == 200:
    credits_data = credits_response.json()
    print("CREW :")
    crew = credits_data.get("crew", []) 
    filtered_roles = ["Director", "Screenplay", "Producer", "Writer", "Composer"]
    filtered_crew = [
        member for member in crew if member.get("job") in filtered_roles
    ]
    for member in filtered_crew[:5]:  # 上位5人まで
        name = member.get("name", "N/A")
        job = member.get("job", "N/A")
        print(f"-  {job}:{name}")
    
    print("CAST :")
    cast = credits_data.get("cast", [])
    for actor in cast[:5]:
        name = actor.get("name", "N/A")
        character = actor.get("character", "N/A")
        print(f"- {name} ({character})")
        profile_path = actor.get("profile_path", None)
        print("profile_path :", profile_path)
    
else:
# ステータスコードが200以外の場合
    print("API Error")

#　レビュー情報の取得
reviews_url = f"https://api.themoviedb.org/3/movie/{movie_id}/reviews"
reviews_params = {
    "api_key": api_key, 
    "language": "en-US",
}    
    
reviews_response = requests.get(reviews_url, params= reviews_params)

if reviews_response.status_code == 200:
    reviews_data = reviews_response.json()
    reviews = reviews_data.get("results",[])
    if reviews:
        print("reviews :")
        for review in reviews[:3]: 
            author = review.get("author", "Unknown")
            content = review.get("content", "No content")
            print(f"Reviewer: {author}")
            print(f"Review: {content}\n")
    else:
        print("None")
else:
# ステータスコードが200以外の場合
    print("API Error")
# Out:
# title :  トップガン マーヴェリック
# original title : Top Gun: Maverick
# overview : マーヴェリック(トム・クルーズ)は、かつて自身も厳しい訓練に挑んだアメリカ海軍パイロットのエリート養成学校、通称「トップガン」に教官として戻ってくる。父親と親友を空で失った過去を持つ彼の型破りな指導に、訓練生たちは反発する。彼らの中には、かつてマーヴェリックの相棒だったグースの息子ルースター(マイルズ・テラー)もいた。
# release_date :  2022-05-21
# runtime: 131
# vote_average : 8.196
# vote_count : 9256
# file_path :  /qw19Vqa16HlmKyxCADncAlb0SWg.jpg
# CREW :
# -  Screenplay:Ehren Kruger
# -  Screenplay:Eric Warren Singer
# -  Screenplay:Christopher McQuarrie
# -  Producer:Christopher McQuarrie
# -  Director:Joseph Kosinski
# CAST :
# - Tom Cruise (Capt. Pete 'Maverick' Mitchell)
# profile_path : /3mShHjSQR7NXOVbdTu5rT2Qd0MN.jpg
# - Miles Teller (Lt. Bradley 'Rooster' Bradshaw)
# profile_path : /cg3LW0xX6RKr8dmescxq1bepcb5.jpg
# - Monica Barbaro (Lt. Natasha 'Phoenix' Trace)
# profile_path : /fcujBTiKyZgJzaDenhv5ryo9SyB.jpg
# - Lewis Pullman (Lt. Robert 'Bob' Floyd)
# profile_path : /jAo0Rxl9EYVxLnhUlBww5Uxl89v.jpg
# - Jay Ellis (Lt. Reuben 'Payback' Fitch)
# profile_path : /78JH7CfMrWrI3Vx2XLbx0GW4c2X.jpg
# reviews :
# Reviewer: r96sk
# Review: What an excellent sequel - I, in fact, like it more than its predecessor.
#
# <em>'Top Gun: Maverick'</em> is fantastic, simply put. I was expecting it to be good, but it's actually much more enjoyable than I had anticipated. The callbacks to the original are expertly done, the new characters are strong/well cast, it has plenty of meaning, music is fab and the action is outstanding - the aerial stuff is sensational.
#
# The story is superb, with each high stake coming across as intended - parts even gave me slight goosebumps, which is a surprise given I'm not someone who has a connection to the 1986 film. It's all super neatly put together, I honestly came close to giving it a higher rating.
#
# Tom Cruise is brilliant as he reprises the role of Maverick, while Miles Teller comes in and gives a top performance. Jennifer Connelly is another positive, though her role does kinda feel a tiny bit forced in order to have a love interest; given Kelly McGillis' [unexplained] absence.
#
# Monica Barbaro stands out most from the fresh faces, though I actually did enjoy watching them all - which is something I thought the film may struggle with, adding new people, but it's done nicely; sure Jon Hamm and Glen Powell are a little cliché, though overall I approve.
#
# A great watch - I'd highly recommend it, though naturally would suggest watching the previous film first if you haven't already.
#
# Reviewer: Manuel São Bento
# Review: FULL SPOILER-FREE REVIEW @ https://www.msbreviews.com/movie-reviews/top-gun-maverick-spoiler-free-review
#
# "Top Gun: Maverick is the return of pure, nostalgic blockbusters, instantly becoming one of this year's personal favorites. The best aerial action sequences ever amaze even the highest expectations, not only due to the absolutely insane real stunts but largely because of the flawless contribution of all filmmaking elements.
#
# The surprisingly emotional screenplay helps Tom Cruise deliver one of the best performances of his career. Perfect editing is essential to creating such realism, as well as raising the tension levels for one of the best final acts within the respective genre.
#
# And, finally, the memorable score loaded with epic tracks makes the theater experience the only way this magnificent work should be seen.
#
# Superior to the original in every way."
#
# Rating: A-
#
# Reviewer: tmdb20895531
# Review: A lot of things in this movie do not make sense, like "why not use F-35?", "why didn't cruise missiles target enemy air defence and planes in hangars?" to name a few.
#
# The original movie had some seriousness built into it, the sequel I think is closer to a comic book movie. Very similar to the original star wars, especially the action sequence at the end. Just a tad more realistic than black widow, you can clearly see the action comedy style of Marvel movies.
#
# I think a lot of conservatives reminiscing Reagan years would watch it, that should be enough to make it a hit.
#
# I think that is also the reason of the high score. To me the movie quality is more of 5 ~ 7 out of 10.
#
# Just don't think too much when watching it, but I don't think that is too big a problem for the target audience.

# %% [markdown]
# 可視化する。ここでやったこと
# １．タイトルを入れる
# ２．入力用の説明を書く
# ３．入力用の箱をつくる
# ４．ユーザー入力前、APIリクエストをスキップするように条件分岐を追加
# ５．文字出力（print）を「st.write」に置き換え
# ６．画像出力（print）を「st.image」に置き換え（サイズも調整）
# ７．画像取得先のURLを追加（生成AIの教え）：
# 　　TMDb APIから返されるfile_pathは、画像URL全体ではなく画像パスのみです。そのままst.image()に渡しても、画像を表示できません。
# 　　TMDb APIの画像表示にはベースURL（https://image.tmdb.org/t/p/）を付加してフルURLを構築する必要があります。
# 　　（１）TMDb APIのレスポンスから得たfile_pathを使い、フルURLを構築する
# 　　（２）構築したフルURLをst.image()に渡す
# ８．APIのステータスコードが「２００以外」のときのエラー表示の分岐を一つにまとめ「映画情報の取得に失敗しました。」のメッセージにした。
# ９．表示項目を日本語へ。また、データが無い時はN/Aを表示、単位を表示

# %%
import requests
import streamlit as st
import difflib

# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"

# Streamlitアプリの構成
st.title("映画情報検索アプリ")
st.write("映画のタイトルを入力して、詳細情報を取得してください。")

# ユーザーが映画タイトルを入力
movie_title = st.text_input("") #説明なくてもよさそうなので空欄

#ユーザー入力前、APIリクエストをスキップするように条件分岐を追加
if movie_title:
    title = movie_title

    # APIのURLを生成
    search_url = "https://api.themoviedb.org/3/search/movie"
    search_params = {
        "api_key": api_key,
        "query": title,
        "include_adult": "false",
        "language": "ja",
    }

    # APIを呼び出す(映画ID取得用)
    search_response = requests.get(search_url, params=search_params)
    if search_response.status_code == 200:
        search_data = search_response.json()

        # タイトルの類似度を評価して最も近い映画を選択
        def get_title_similarity(s1, s2):
            return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()

        most_similar_movie = max(
            search_data["results"],
            key=lambda movie: get_title_similarity(movie["title"], title)
        )
        movie_id = most_similar_movie["id"]

        # 映画詳細情報の取得
        detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"
        detail_params = {"api_key": api_key, "language": "ja"}
        detail_response = requests.get(detail_url, params=detail_params)
        if detail_response.status_code == 200:
            detail_data = detail_response.json()
            st.write("### 映画情報")
            st.write(f"**タイトル**: {detail_data.get('title', 'N/A')}")
            st.write(f"**オリジナルタイトル**: {detail_data.get('original_title', 'N/A')}")
            st.write(f"**概要**: {detail_data.get('overview', 'N/A')}")
            st.write(f"**公開日**: {detail_data.get('release_date', 'N/A')}")
            st.write(f"**上映時間**: {detail_data.get('runtime', 'N/A')} 分")
            st.write(f"**評価スコア** :{detail_data.get('vote_average', 'N/A')} /10")
            st.write(f"**評価数** :{detail_data.get('vote_count', 'N/A')} 件")
         
         # ポスター情報の取得
        images_url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
        poster_size = "w300" 

        images_params = {
            "api_key": api_key, 
            "include_image_language": "ja",
        }   
        images_response = requests.get(images_url, images_params)
        if images_response.status_code == 200:
            images_data = images_response.json()
            posters = images_data.get("posters", [])
            if posters:
                file_path = posters[0].get("file_path")
                full_image_url = f"https://image.tmdb.org/t/p/{poster_size}{file_path}"  # フルURLを構築
                st.image(full_image_url)  # フルURLを渡して画像を表示
            else:
                st.write("ポスター画像が見つかりませんでした。")
        else:
            st.write("ポスター画像の取得に失敗しました。")

            
        # 製作者、キャストの情報取得
        credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"
        credits_params = {"api_key": api_key, "language": "ja"}
        credits_response = requests.get(credits_url, params=credits_params)
        if credits_response.status_code == 200:
            credits_data = credits_response.json()
            if credits_response.status_code == 200:
                credits_data = credits_response.json()
                
                st.write("### 製作者情報")
                crew = credits_data.get("crew", []) 
                filtered_roles = ["Director", "Screenplay", "Producer", "Writer", "Composer"]
                filtered_crew = [
                member for member in crew if member.get("job") in filtered_roles
                ]
                for member in filtered_crew[:5]:  # 上位5人まで
                    name = member.get("name", "N/A")
                    job = member.get("job", "N/A")
                    st.write(f"- {job}:{name} ")
                    
            st.write("### キャスト情報")
            cast = credits_data.get("cast", [])
            for actor in cast[:5]:
                name = actor.get("name", "N/A")
                character = actor.get("character", "N/A")
                st.write((f"- {name} ( {character} )"))
                profile_path = actor.get("profile_path", None)
                if profile_path:
                    profile_url = f"https://image.tmdb.org/t/p/w200{profile_path}"
                    st.image(profile_url,width=100)  
                    #画像サイズが大きかったので調整（url部分を直そうとしたらエラーとなったので、ここで調整）
                else:
                    st.write(f"- {name} as {character} (No image available)")
    else:
        st.write("映画情報の取得に失敗しました。")
    
    # レビュー情報の取得     
    reviews_url = f"https://api.themoviedb.org/3/movie/{movie_id}/reviews"
    reviews_params = {
        "api_key": api_key, 
        "language": "en-US",
    }    
    
    reviews_response = requests.get(reviews_url, params= reviews_params)

    reviews_data = reviews_response.json()
    reviews = reviews_data.get("results",[])
    if reviews:
        st.write("### レビュー :")
        for review in reviews[:3]: 
            author = review.get("author", "Unknown")
            content = review.get("content", "No content")
            st.write(f"Reviewer : {author}さんのレビュー")
            st.write(f"Review : {content}\n")
    else:
        print("レビューはありません")
else:
    st.write("") #説明なくてもよさそうなので空欄
# Out:
# 2024-12-12 23:48:44.120 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.433
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\macco\miniconda3\envs\test2\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-12-12 23:48:44.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.447 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-12-12 23:48:44.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.450 Session state does not function when running a script without `streamlit run`
# 2024-12-12 23:48:44.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# 見た目の整え作業（ここでやったこと）
# １．ポスター画像を映画タイトルの下へ
# ２．映画のタイトル文字を大きくし（st.subheader使用）、オリジナルタイトルをタイトルの横に表示
# ３．「概要」の文字削除
# ４．～さんのレビューの文字を太字に

# %%
import requests
import streamlit as st
import difflib

# APIキーを指定
api_key = "054f72271ae8d8ea2beea5ae520ca6d2"

# Streamlitアプリの構成
st.title("映画情報検索アプリ")
st.write("映画のタイトルを入力して、詳細情報を取得してください。")

# ユーザーが映画タイトルを入力
movie_title = st.text_input("") #説明なくてもよさそうなので空欄

#ユーザー入力前、APIリクエストをスキップするように条件分岐を追加
if movie_title:
    title = movie_title

    # APIのURLを生成
    search_url = "https://api.themoviedb.org/3/search/movie"
    search_params = {
        "api_key": api_key,
        "query": title,
        "include_adult": "false",
        "language": "ja",
    }

    # APIを呼び出す(映画ID取得用)
    search_response = requests.get(search_url, params=search_params)
    if search_response.status_code == 200:
        search_data = search_response.json()

        # タイトルの類似度を評価して最も近い映画を選択
        def get_title_similarity(s1, s2):
            return difflib.SequenceMatcher(None, s1.lower(), s2.lower()).ratio()

        most_similar_movie = max(
            search_data["results"],
            key=lambda movie: get_title_similarity(movie["title"], title)
        )
        movie_id = most_similar_movie["id"]

        # 映画詳細情報の取得
        detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}"
        detail_params = {"api_key": api_key, "language": "ja"}
        detail_response = requests.get(detail_url, params=detail_params)
        if detail_response.status_code == 200:
            detail_data = detail_response.json()
            
              # ポスター情報の取得
            images_url = f"https://api.themoviedb.org/3/movie/{movie_id}/images"
            poster_size = "w300" 

            images_params = {
                "api_key": api_key, 
                "include_image_language": "ja",
            }   
            images_response = requests.get(images_url, images_params)
            if images_response.status_code == 200:
                images_data = images_response.json()
                posters = images_data.get("posters", [])
                if posters:
                    file_path = posters[0].get("file_path")
                    full_image_url = f"https://image.tmdb.org/t/p/{poster_size}{file_path}"  # フルURLを構築st.write("### 映画情報")
                    
            #映画情報とポスターを表示
            st.subheader(f"{detail_data['title']} ({detail_data['original_title']})")
            if full_image_url:
                st.image(full_image_url)
            st.write(f" {detail_data.get('overview', 'N/A')}")
            st.write(f"**公開日**: {detail_data.get('release_date', 'N/A')}")
            st.write(f"**上映時間**: {detail_data.get('runtime', 'N/A')} 分")
            st.write(f"**評価スコア** :{detail_data.get('vote_average', 'N/A')} /10")
            st.write(f"**評価数** :{detail_data.get('vote_count', 'N/A')} 件")

            
        # 製作者、キャスト情報の取得
        credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"
        credits_params = {"api_key": api_key, "language": "ja"}
        credits_response = requests.get(credits_url, params=credits_params)
        if credits_response.status_code == 200:
            credits_data = credits_response.json()
            
            st.write("### 製作者情報")
            crew = credits_data.get("crew", []) 
            filtered_roles = ["Director", "Screenplay", "Producer", "Writer", "Composer"]
            filtered_crew = [
            member for member in crew if member.get("job") in filtered_roles
            ]
            for member in filtered_crew[:5]:  # 上位5人まで
                name = member.get("name", "N/A")
                job = member.get("job", "N/A")
                st.write(f"- {job}:{name}")

            st.write("### キャスト情報")
            cast = credits_data.get("cast", [])
            for actor in cast[:5]:
                name = actor.get("name", "N/A")
                character = actor.get("character", "N/A")
                profile_path = actor.get("profile_path", None)
                st.write((f"- {name} ( {character} )"))
                if profile_path:
                    profile_url = f"https://image.tmdb.org/t/p/w200{profile_path}"
                    st.image(profile_url,width=100)  
                    #画像サイズが大きかったので調整（url部分を直そうとしたらエラーとなったので、ここで調整）
                else:
                    st.write("(No image available)")

    else:
        st.write("映画情報の取得に失敗しました。")
   
    #　レビュー情報の取得
    reviews_url = f"https://api.themoviedb.org/3/movie/{movie_id}/reviews"
    reviews_params = {
        "api_key": api_key, 
        "language": "en-US",
    }    
    
    reviews_response = requests.get(reviews_url, params= reviews_params)

    reviews_data = reviews_response.json()
    reviews = reviews_data.get("results",[])
    if reviews:
        st.write("### レビュー")
        for review in reviews[:3]: 
            author = review.get("author", "Unknown")
            content = review.get("content", "No content")
            st.write(f"**Reviewer :  {author}さんのレビュー**")
            st.write(f"Review :  {content}\n")
    else:
        print("None")
else:
    st.write("") #説明なくてもよさそうなので空欄
# Out:
# 2024-12-12 23:48:44.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.489 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-12-12 23:48:44.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-12 23:48:44.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
pip show streamlit
# Out:
# Name: streamlit
# Version: 1.40.1
# Summary: A faster way to build and share data apps
# Home-page: https://streamlit.io
# Author: Snowflake Inc
# Author-email: hello@streamlit.io
# License: Apache License 2.0
# Location: c:\users\macco\miniconda3\envs\test2\lib\site-packages
# Requires: altair, blinker, cachetools, click, gitpython, numpy, packaging, pandas, pillow, protobuf, pyarrow, pydeck, requests, rich, tenacity, toml, tornado, typing-extensions, watchdog
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: c:\users\macco\miniconda3\envs\test2\lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: jupyterlab_server, streamlit
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show difflib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: difflib

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.
